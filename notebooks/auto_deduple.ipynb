# %% [markdown]
# # **Automatic Deduplication**
#
# Deduplication of SIVEP-GRIPE stored in the warehouse using trained ML models.<br>

# %% [markdown]
# # **Lib**

# %%
import os
import sys
sys.path.append( os.path.dirname(os.path.abspath('')) )

# %%
import json
import glob
import shutil
import joblib
import zipfile
from tqdm import tqdm
import numpy as np
import pandas as pd
import datetime as dt
from simpledbf import Dbf5

import matplotlib.pyplot as plt
# Out:
# PyTables is not installed. No support for HDF output.

# %%
from epimonitor import WarehouseSUS
from epimonitor.process_layer import ProcessSivep
from epimonitor.data_matching import Deduple

# %% [markdown]
# # **Database Connection**

# %%
datapath = os.path.join(os.environ["HOMEPATH"], "Documents", "data")
basepath = os.path.join(os.environ["HOMEPATH"], "Documents", "data", "SIVEP-GRIPE")
dbpath = os.path.join(datapath, "DATASUS_WAREHOUSE", "datasus_pessoas.db") # it shouldn't be here in this script
engine_url = f"sqlite:///{dbpath}"

warehouse = WarehouseSUS(engine_url)
engine = warehouse.db_init()

# %%
print(f"Tables: \n{list(warehouse.tables.keys())}")
# Out:
# Tables:
# ['sivep_gripe', 'label_sivep_gripe']

# %%
nrecords = warehouse.number_of_records('sivep_gripe')
print(f"Total of records stored: {nrecords}")
# Out:
# Total of records stored: 100362

# %%
nrecords = warehouse.number_of_records('label_sivep_gripe')
print(f"Total of records stored: {nrecords}")
# Out:
# Total of records stored: 3631743

# %%
# -- delete table
#warehouse.delete_table('label_sivep_gripe', is_sure=True, authkey="###!Y!.")

# %%
len(warehouse.query_where('label_sivep_gripe', value=0.50, colname="PROBA_NEGATIVO_MODELO_3", condition='smaller'))
# Out:
# 8685

# %% [markdown]
# # **Deduplication**

# %%
query_pairs = pd.DataFrame( warehouse.query_all(table_name='label_sivep_gripe') )
if query_pairs.shape[0]>0:
    query_pairs = query_pairs[["ID1", "ID2"]].copy()
else:
    query_pairs = []

# %%
query_pairs[:5]
# Out:
#               ID1             ID2
# 0    315968354539  31644621350086
# 1    316361280151  31649265573775
# 2    315894600446    315913747766
# 3    316179890440    316197135821
# 4  31655020136248  31659449463012

# %%
if len(query_pairs):
    query_pairs = list(query_pairs.itertuples(index=False, name=None))

# %%
period = (dt.datetime(2020, 1, 1), dt.datetime.today())
query_data = pd.DataFrame( warehouse.query_period(table_name='sivep_gripe', date_col="DATA_NOTIFICACAO", period=period) ).sample(frac=0.5)

# %%
print(query_data.info())
query_data.sample(n=4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49748 entries, 5769 to 67633
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_SIVEP              49748 non-null  object
#  1   DATA_NOTIFICACAO      49748 non-null  datetime64[ns]
#  2   NOME_PACIENTE         49748 non-null  object
#  3   DATA_NASCIMENTO       49702 non-null  datetime64[ns]
#  4   SEXO                  49748 non-null  object
#  5   NOME_MAE              48415 non-null  object
#  6   LOGRADOURO            48600 non-null  object
#  7   LOGRADOURO_NUMERO     46079 non-null  object
#  8   BAIRRO_RESIDENCIA     46975 non-null  object
#  9   MUNICIPIO_RESIDENCIA  49747 non-null  object
#  10  CEP                   29513 non-null  object
#  11  CNS                   12319 non-null  object
#  12  CPF                   26597 non-null  object
#  13  CNES                  49748 non-null  object
#  14  DATA_SINTOMAS         49748 non-null  datetime64[ns]
#  15  CLASSIFICACAO_FINAL   38448 non-null  object
#  16  CRITERIO              36438 non-null  object
#  17  EVOLUCAO              36152 non-null  object
#  18  CRIADO_EM             49748 non-null  datetime64[ns]
#  19  ATUALIZADO_EM         49748 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(15)
# memory usage: 8.0+ MB
# None
#              ID_SIVEP DATA_NOTIFICACAO                     NOME_PACIENTE  \
# 41053    316167898058       2021-03-26           GILBERTO GOMES DA SILVA
# 28654    316118549218       2021-01-12  KEVIN ERIK SILVA LOIOLA PINHEIRO
# 38711    316160338422       2021-03-17          JOSE WELTON ANGELO SOUSA
# 84566  31654476667626       2022-06-05      DEIVID LEVY DA SILVA BEZERRA
#
#       DATA_NASCIMENTO SEXO                    NOME_MAE             LOGRADOURO  \
# 41053      1966-03-24    M     ROSA GONCALVES DA SILVA                TATIANA
# 28654      2012-12-13    M   MARIA ERIDAM SILVA LOIOLA   RUA FRANCISCO PASTOR
# 38711      1983-04-21    M  ANTONIA MARIA ANGELO SOUSA  RUA CARNEIRO DA CUNHA
# 84566      2022-02-13    M       SAMIRA DA SILVA BRITO     RUA ESTUDANTE JUCA
#
#       LOGRADOURO_NUMERO BAIRRO_RESIDENCIA MUNICIPIO_RESIDENCIA       CEP  \
# 41053                38        VILA VELHA               230440  60349385
# 28654               136         CARAPIOCA               230625      None
# 38711               477              None               230440      None
# 84566                 2           SERINHA               230440      None
#
#                    CNS          CPF     CNES DATA_SINTOMAS  \
# 41053  706008311728244         None  2529149    2021-03-23
# 28654             None         None  2563681    2021-01-11
# 38711             None         None  7434308    2021-03-11
# 84566             None  12417265311  2526638    2022-06-04
#
#       CLASSIFICACAO_FINAL CRITERIO EVOLUCAO                  CRIADO_EM  \
# 41053                   5        1        1 2023-09-05 13:16:15.183919
# 28654                   4        1        1 2023-09-05 13:16:12.960028
# 38711                None     None     None 2023-09-05 13:16:14.668067
# 84566                None     None     None 2023-09-05 13:16:55.338362
#
#                    ATUALIZADO_EM
# 41053 2023-09-05 13:16:15.183919
# 28654 2023-09-05 13:16:12.960028
# 38711 2023-09-05 13:16:14.668067
# 84566 2023-09-05 13:16:55.338362

# %% [markdown]
# ## **Process Sivep**

# %%
processor = ProcessSivep(query_data, 'ID_SIVEP')

# %%
processor.basic_standardize().specific_standardize()

# %%
processed_data = processor.data.copy()
processed_data.sample(n=4)
# Out:
#            ID_SIVEP                 NOME_PACIENTE                   NOME_MAE  \
# 25633  316415792398           BENONY CUNHA GALVAO     MARIANA ALVES DA CUNHA
# 42338  315980078574     FRANCISCO CLECIO DE SOUZA     MARIA CILEIDE DE SOUZA
# 14084  316315394449  MARIA EDILMA DA SILVA CASTRO       MARIA PEDRO DA SILVA
# 19646  316269814434   OSMARINO RODRIGUES DE SOUSA  QUERINA LOIOLA MAIA SOUSA
#
#       DATA_NASCIMENTO primeiro_nome        complemento_nome primeiro_nome_mae  \
# 25633      1948-08-14        BENONY            CUNHA GALVAO           MARIANA
# 42338      1977-02-10     FRANCISCO         CLECIO DE SOUZA             MARIA
# 14084      1936-08-15         MARIA  EDILMA DA SILVA CASTRO             MARIA
# 19646      1942-03-07      OSMARINO      RODRIGUES DE SOUSA           QUERINA
#
#       complemento_nome_mae  nascimento_dia  nascimento_mes  ...  \
# 25633       ALVES DA CUNHA            14.0             8.0  ...
# 42338     CILEIDE DE SOUZA            10.0             2.0  ...
# 14084       PEDRO DA SILVA            15.0             8.0  ...
# 19646    LOIOLA MAIA SOUSA             7.0             3.0  ...
#
#            FONETICA_N norm_primeiro_nome  rank_primeiro_nome  \
# 25633    BENONYGALVAO           0.000040                   2
# 42338  FRANCISCOSOUZA           0.068385                   6
# 14084     MARIACASTRO           0.148468                   7
# 19646   OSMARINOSOUSA           0.000040                   2
#
#       norm_primeiro_nome_mae  rank_primeiro_nome_mae sexo          cpf  \
# 25633               0.001648                       4    M         None
# 42338               0.320576                       7    M  75642786334
# 14084               0.320576                       7    F  46965610387
# 19646               0.000040                       2    M  26631512387
#
#                    cns        bairro       cep
# 25633  708200129598745  PANAMERICANO       NaN
# 42338              NaN     SAO BENTO  60875135
# 14084              NaN       ITAPERI  60714390
# 19646  700004398455803        CENTRO  63660000
#
# [4 rows x 21 columns]

# %% [markdown]
# **TOP 10 names**

# %%
processor.freq_names[:10]
# Out:
#   primeiro_nome  norm_primeiro_nome rank_primeiro_nome primeiro_nome_mae  \
# 0         MARIA            0.148468                  7             MARIA
# 1     FRANCISCO            0.068385                  6         FRANCISCA
# 2          JOSE            0.063540                  6          RAIMUNDA
# 3       ANTONIO            0.032142                  6           ANTONIA
# 4          JOAO            0.025991                  6               ANA
# 5           ANA            0.025870                  6              RITA
# 6     FRANCISCA            0.025147                  6             LUIZA
# 7      RAIMUNDO            0.015357                  5             JOANA
# 8         PEDRO            0.012201                  5            JOSEFA
# 9       ANTONIA            0.011016                  5              ROSA
#
#    norm_primeiro_nome_mae rank_primeiro_nome_mae
# 0                0.320576                      7
# 1                0.076727                      6
# 2                0.033408                      6
# 3                0.029489                      6
# 4                0.029227                      6
# 5                0.010191                      5
# 6                0.008322                      5
# 7                0.007739                      5
# 8                0.007116                      5
# 9                0.006030                      5

# %% [markdown]
# ## **Deduple**

# %% [markdown]
# **Load classifiers**

# %%
gbt_model = joblib.load(os.path.join(basepath, "TRAINED_MODELS", "GRADBOOST_SIVEP04SET2023.joblib"))
rnf_model = joblib.load(os.path.join(basepath, "TRAINED_MODELS", "RANDFOREST_SIVEP04SET2023.joblib"))
lgt_model = joblib.load(os.path.join(basepath, "TRAINED_MODELS", "LOGITREG_SIVEP04SET2023.joblib"))

# %% [markdown]
# **Prepare similarity matrix**

# %%
#dedupe_path = os.path.join(datapath, "SIVEP-GRIPE", "TRAINING_DATA_CLASSIFIER", "DEDUPE_FILES")

deduple = Deduple(processed_data, left_id="ID_SIVEP", env_folder=None)
map_compare = {
    "cns": ["exact"], "cep": ["exact"], "cpf": ["exact"], "sexo": ["exact"],
    "nascimento_dia": ["exact"], "nascimento_mes": ["exact"], "nascimento_ano": ["exact"],
    "primeiro_nome_mae": ["string", None], "complemento_nome_mae": ["string", None],
    "primeiro_nome": ["string", None], 
    "complemento_nome": ["string", None], "bairro": ["string", None]
}

deduple.set_linkage(map_compare, string_method="damerau_levenshtein").define_pairs("FONETICA_N", window=3)
# Out:
# Number of pairs: 1665947

# %%
#index0 = [(1,2), (1,3), (3,1)]
#pd.MultiIndex.from_tuples(index0, names=["ID_SIVEP_1", "ID_SIVEP_2"])

#list({*map(tuple, map(sorted, index0))})

#self.candidate_pairs = pd.MultiIndex.from_tuples(  )
#list(deduple.candidate_pairs)

# %%
# -- remove pairs that were already classified before
deduple.candidate_pairs = deduple.candidate_pairs.drop(query_pairs, errors='ignore')
print(deduple.candidate_pairs.shape[0])
deduple.candidate_pairs[:10]
# Out:
# 1053613
# MultiIndex([(  '316420850322', '31665084311594'),
#             (  '316158191999',   '316333573427'),
#             (  '316192848973', '31657550865734'),
#             (  '315912761636', '31642618704284'),
#             (  '315881342251',   '316309277782'),
#             ('31670592168274', '31679951223873'),
#             (  '316179110346',   '316420696523'),
#             (  '315886168941',   '315960305534'),
#             (  '315862891614',   '316268880129'),
#             (  '315978330035',   '316182446462')],
#            names=['ID_SIVEP_1', 'ID_SIVEP_2'])

# %%
deduple.perform_linkage("FONETICA_N", window=3, threshold=0.60)

# %%
ranks = processed_data.set_index('ID_SIVEP')[["rank_primeiro_nome", "rank_primeiro_nome_mae"]]
deduple._comparison_matrix = deduple.comparison_matrix.merge(ranks, left_on=["ID_SIVEP_1"], right_index=True, how="left")
deduple._comparison_matrix["rank_primeiro_nome_mae"] = deduple._comparison_matrix["rank_primeiro_nome_mae"].fillna(7)

# %%
deduple.comparison_matrix.sample(n=5)
# Out:
#                              cns  cep  cpf  sexo  nascimento_dia  \
# ID_SIVEP_1   ID_SIVEP_2
# 316021772672 316111706330      0    0    0     1               0
# 316178895123 31663867763817    0    0    0     1               0
# 315889495649 31682804060221    0    0    0     1               0
# 315910401539 316178919079      0    0    0     1               0
# 316139193334 31643032112118    0    0    0     1               0
#
#                              nascimento_mes  nascimento_ano  \
# ID_SIVEP_1   ID_SIVEP_2
# 316021772672 316111706330                 0               0
# 316178895123 31663867763817               0               0
# 315889495649 31682804060221               0               0
# 315910401539 316178919079                 0               0
# 316139193334 31643032112118               0               0
#
#                              primeiro_nome_mae  complemento_nome_mae  \
# ID_SIVEP_1   ID_SIVEP_2
# 316021772672 316111706330                  0.0                   0.0
# 316178895123 31663867763817                0.0                   0.0
# 315889495649 31682804060221                1.0                   0.0
# 315910401539 316178919079                  0.0                   0.0
# 316139193334 31643032112118                0.0                   0.0
#
#                              primeiro_nome  complemento_nome  bairro  \
# ID_SIVEP_1   ID_SIVEP_2
# 316021772672 316111706330              1.0               0.0     0.0
# 316178895123 31663867763817            1.0               0.0     0.0
# 315889495649 31682804060221            1.0               0.0     0.0
# 315910401539 316178919079              1.0               0.0     0.0
# 316139193334 31643032112118            1.0               0.0     0.0
#
#                             rank_primeiro_nome rank_primeiro_nome_mae
# ID_SIVEP_1   ID_SIVEP_2
# 316021772672 316111706330                    7                      4
# 316178895123 31663867763817                  5                      4
# 315889495649 31682804060221                  7                      7
# 315910401539 316178919079                    7                      6
# 316139193334 31643032112118                  7                      6

# %% [markdown]
# **Classify pairs**

# %%
matrix_pairs = deduple.comparison_matrix.reset_index().copy()
pair_ids, X_sel = matrix_pairs.iloc[:,:2],  matrix_pairs.iloc[:,2:].values

# %%
batchsize = 6000
Y_neg1, Y_neg2, Y_neg3 = [], [], []
for batch in tqdm(np.array_split(X_sel, np.arange(batchsize, X_sel.shape[0]+1, batchsize))):
    Y_neg1 += [ res[0] for res in gbt_model.predict_proba(batch) ]
    Y_neg2 += [ res[0] for res in rnf_model.predict_proba(batch) ]
    Y_neg3 += [ res[0] for res in lgt_model.predict_proba(batch) ]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 176/176 [00:23<00:00,  7.44it/s]

# %%
pair_ids["FMT_PKEY"] = pair_ids["ID_SIVEP_1"] + "-" + pair_ids["ID_SIVEP_2"]
pair_ids["PROBA_NEGATIVO_MODELO_1"] = Y_neg1
pair_ids["PROBA_NEGATIVO_MODELO_2"] = Y_neg2
pair_ids["PROBA_NEGATIVO_MODELO_3"] = Y_neg3
#pair_ids["LABEL_MODELO_1"] = pair_ids["PROBA_NEGATIVO_MODELO_1"].apply(lambda x: 0 if x>=0.50 else 1)
#pair_ids["LABEL_MODELO_2"] = pair_ids["PROBA_NEGATIVO_MODELO_2"].apply(lambda x: 0 if x>=0.50 else 1)
#pair_ids["LABEL_MODELO_3"] = pair_ids["PROBA_NEGATIVO_MODELO_3"].apply(lambda x: 0 if x>=0.50 else 1)

# %%
pair_ids
# Out:
#            ID_SIVEP_1      ID_SIVEP_2                     FMT_PKEY  \
# 0        316420850322  31665084311594  316420850322-31665084311594
# 1        316158191999    316333573427    316158191999-316333573427
# 2        316192848973  31657550865734  316192848973-31657550865734
# 3        315912761636  31642618704284  315912761636-31642618704284
# 4        315881342251    316309277782    315881342251-316309277782
# ...               ...             ...                          ...
# 1053608  315924127454  31655183873441  315924127454-31655183873441
# 1053609  315977588012    316184083012    315977588012-316184083012
# 1053610  316037215205    316158167791    316037215205-316158167791
# 1053611  315925981683    316247091982    315925981683-316247091982
# 1053612  316170421021    316182389812    316170421021-316182389812
#
#          PROBA_NEGATIVO_MODELO_1  PROBA_NEGATIVO_MODELO_2  \
# 0                       0.999954                 0.999714
# 1                       0.999954                 0.999742
# 2                       0.999928                 0.998082
# 3                       0.999954                 0.995613
# 4                       0.999954                 0.999742
# ...                          ...                      ...
# 1053608                 0.999928                 0.998082
# 1053609                 0.999928                 0.995841
# 1053610                 0.999954                 0.999745
# 1053611                 0.999954                 0.999742
# 1053612                 0.999954                 0.999714
#
#          PROBA_NEGATIVO_MODELO_3
# 0                       1.000000
# 1                       1.000000
# 2                       1.000000
# 3                       1.000000
# 4                       1.000000
# ...                          ...
# 1053608                 1.000000
# 1053609                 0.999999
# 1053610                 1.000000
# 1053611                 1.000000
# 1053612                 1.000000
#
# [1053613 rows x 6 columns]

# %% [markdown]
# ## Inject compared pairs in the warehouse

# %%
#warehouse.insert('label_sivep_gripe', pair_ids, batchsize=1000, verbose=True)

# %%
#warehouse.delete_table('label_sivep_gripe', is_sure=True, authkey="###!Y!.")
