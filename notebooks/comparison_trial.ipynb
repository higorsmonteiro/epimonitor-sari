# %%
import os
import sys
sys.path.append("..")
sys.path.append(os.path.join("..", "..", "linkage-saude"))

# %%
import numpy as np
import pandas as pd
import datetime as dt
from simpledbf import Dbf5
# Out:
# PyTables is not installed. No support for HDF output.

# %%
from linkage_saude.matching import PLinkage

# %%
from injectsus import WarehouseSUS
from injectsus.process_layer import ProcessBase, ProcessSivep

# %% [markdown]
# ## Inject data

# %%
basepath = os.path.join(os.environ["HOMEPATH"], "Documents", "data")
siveppath = os.path.join(basepath, "SIVEP-GRIPE", "MILLENA_14JUN2023")
fname = "SRAGHOSPITALIZADO1930520_00.dbf"

sivep_df = Dbf5(os.path.join(siveppath, fname), codec="latin").to_dataframe()
sample_df = sivep_df.copy()
#sample_df = sivep_df.sample(n=500, random_state=1)

sample_df1 = sample_df.copy()
sample_df1["DT_NASC"] = pd.to_datetime(sample_df1["DT_NASC"], format="%d/%m/%Y", errors="coerce")
sample_df1["DT_NOTIFIC"] = pd.to_datetime(sample_df1["DT_NOTIFIC"], format="%d/%m/%Y", errors="coerce")
print(sample_df1.shape)
sample_df1.sample(n=4)
# Out:
# (5305, 221)
#      DT_RES_AN RES_AN LAB_AN CO_LAB_AN POS_AN_FLU TP_FLU_AN POS_AN_OUT  \
# 407        NaN      5    NaN       NaN        NaN       NaN        NaN
# 2940       NaN    NaN    NaN       NaN        NaN       NaN        NaN
# 3221       NaN      5    NaN       NaN        NaN       NaN        NaN
# 1677       NaN    NaN    NaN       NaN        NaN       NaN        NaN
#
#      AN_SARS2 AN_VSR  AN_PARA1  ...                           PAC_DSCBO  \
# 407       NaN    NaN       NaN  ...                                 NaN
# 2940      NaN    NaN       NaN  ...                                 NaN
# 3221      NaN    NaN       NaN  ...  TRABALHADOR VOLANTE DA AGRICULTURA
# 1677      NaN    NaN       NaN  ...                                 NaN
#
#       OUT_ANIM  DOR_ABD FADIGA PERD_OLFT  PERD_PALA TOMO_RES TOMO_OUT  \
# 407        NaN      NaN      1       NaN        NaN      0.0      NaN
# 2940       NaN        2      2         2          2      0.0      NaN
# 3221       NaN      NaN    NaN       NaN        NaN      0.0      NaN
# 1677       NaN      NaN    NaN       NaN        NaN      0.0      NaN
#
#       DT_TOMO TP_TES_AN
# 407       NaN       0.0
# 2940      NaN       0.0
# 3221      NaN       0.0
# 1677      NaN       0.0
#
# [4 rows x 221 columns]

# %%
# -- Paths
basepath = os.path.join(os.environ["HOMEPATH"], "Documents", "data")
suspath = os.path.join(basepath, "DATASUS_WAREHOUSE", "datasus_pessoas.db")
engine_url = f"sqlite:///{suspath}"

warehouse = WarehouseSUS(engine_url)
engine = warehouse.db_init()

# Uncomment if you want to reset table
#warehouse.delete_table('sivep_gripe', is_sure=True, authkey="###!Y!.")
#warehouse.db_init()

#warehouse.insert('sivep_gripe', sample_df1, batchsize=50, verbose=True)

# %%
#warehouse.query_where('sivep_gripe', value="2526638", colname="CNES")

# %% [markdown]
# ## Create API functions

# %% [markdown]
# ## Searching

# %%
def app(table_name):
    '''
        ...
    '''
    basepath = os.path.join(os.environ["HOMEPATH"], "Documents", "data")
    dbpath = os.path.join(basepath, "DATASUS_WAREHOUSE", "datasus_pessoas.db")
    engine_url = f"sqlite:///{dbpath}"
    dbsus = WarehouseSUS(engine_url)
    engine = dbsus.db_init()

    qdata = pd.DataFrame( dbsus.query_all(table_name) )
    objdata = ProcessSivep(qdata, field_id="ID_SIVEP")
    objdata.basic_standardize().specific_standardize()
    proc_data = objdata.data.copy()

    return proc_data

def search_person(record, table_name, not_period, field_id="ID"):
    
    record_df = pd.DataFrame(record).reset_index()
    base_fields = ["NOME_PACIENTE", "DATA_NASCIMENTO", "NOME_MAE"]
    if not all([ elem in record_df.columns for elem in base_fields ]):
        raise Exception()
    
    objdata = ProcessBase(record_df, field_id=field_id)
    objdata.basic_standardize().specific_standardize()
    record_df = objdata.data.copy()

    searchbase = app(table_name)

    linkage = PLinkage(left_df=record_df, right_df=searchbase, left_id=field_id, right_id='ID_SIVEP', env_folder=None)
    
    
    map_compare = {
        "nascimento_dia": ["exact"], "nascimento_mes": ["exact"], "nascimento_ano": ["exact"],
        "primeiro_nome_mae": ["string", None], "complemento_nome_mae": ["string", None],
        "primeiro_nome": ["string", None], "complemento_nome": ["string", None],
    }
    map_sum = {
        "SOMA": list(map_compare.keys()),
        "SOMA ESSENCIAL 1": ["nascimento_dia", "nascimento_mes", "nascimento_ano", "primeiro_nome", "complemento_nome"],
    }
    linkage.set_linkage(map_compare, string_method="damerau_levenshtein")
    linkage.perform_linkage("FONETICA_N", window=3, threshold=0.75)
    comp_matrix = linkage.comparison_matrix.copy()
    comp_matrix["SOMA"] = comp_matrix.apply(sum, axis=1)
    comp_matrix_1 = comp_matrix[comp_matrix["SOMA"]>0].reset_index()
    found_ids = comp_matrix_1["ID_SIVEP"]
    collect = []
    for cur_id in found_ids:
        res = warehouse.query_where('sivep_gripe', value=cur_id, colname='ID_SIVEP')
        collect += res
    
    return pd.DataFrame(collect).drop(["CRIADO_EM", "ATUALIZADO_EM"], axis=1)

# %%
data = app('sivep_gripe')

# %%
record = {"ID": ["HGR1", "FRC2"], 
          "NOME_PACIENTE": ["HIGOR DA SILVA MONTEIRO", "FRANCISCA SOARES BARBOSA"], 
          "DATA_NASCIMENTO": [dt.datetime(1996, 7, 26), dt.datetime(1931, 10, 7)],
          "NOME_MAE": ["DANIELA DA SILVA CAXILE", "MARIA RDIGUES SOARES"] }

out = search_person(record, 'sivep_gripe', None, 'ID')
# Out:
# Number of pairs: 6

# %%
out
# Out:
#          ID_SIVEP DATA_NOTIFICACAO                      NOME_PACIENTE  \
# 0  31682003799083       2023-04-19        FRANCISCA DE PONTES BARRETO
# 1  31684265426043       2023-05-16           FRANCISCA SOARES BARBOSA
# 2  31685731946870       2023-05-09           FRANCISCA SOARES BARBOSA
# 3  31684946006940       2023-05-24  FRANCISCA DJANICE OLIVEIRA ARAUJO
#
#   DATA_NASCIMENTO SEXO                 NOME_MAE                 LOGRADOURO  \
# 0      1930-08-25    F  MARIA DE PONTES BARRETO                  BEIRA MAR
# 1      1931-10-08    F   MARIA RODRIGUES SOARES             FELINO BARROSO
# 2      1931-10-08    F   MARIA RODRIGUES SOARES             FELINO BARROSO
# 3      1973-05-25    F      TEREZA ALVES ARAUJO  CLAUDIO CAMELO TIMBO 1130
#
#   LOGRADOURO_NUMERO BAIRRO_RESIDENCIA MUNICIPIO_RESIDENCIA       CEP   CNS  \
# 0              1020  PRAIA DE IRACEMA               230440  60000000  None
# 1               281            FATIMA               230440  60050130  None
# 2               281            FATIMA               230440  60050130  None
# 3               160            CENTRO               230520  62270970  None
#
#            CPF     CNES
# 0  01819283372  3047091
# 1  32413670378  3242587
# 2  32413670378  3242587
# 3  72875356372  3242587

# %%
import duckdb

# %%
warehouse.query_where('sivep_gripe', value='31677160640902', colname="ID_SIVEP")
# Out:
# [('31677160640902', datetime.datetime(2023, 2, 23, 0, 0), 'HILDA HOLANDA DOS SANTOS', datetime.datetime(1924, 6, 12, 0, 0), 'F', 'MARIA NAZARETH DE HOLANDA', 'SANTA LIGIA', '221', 'PARANGABA', '230440', '60720720', None, '15516121353', '3242587', datetime.datetime(2023, 8, 2, 14, 52, 15, 279306), datetime.datetime(2023, 8, 2, 14, 52, 15, 279306))]

# %%
qres = dbsus.query('sivep_gripe', date_col="DATA_NOTIFICACAO", period=[dt.datetime(2023, 4, 1), None])

# %%
qdata = pd.DataFrame(qres)
qdata
# Out:
#            ID_SIVEP DATA_NOTIFICACAO                    NOME_PACIENTE  \
# 0    31680347753465       2023-04-01      FRANCISCO DHAVY ARANDA REIS
# 1    31680358132567       2023-04-01          JOSE CARLOS SOUSA SILVA
# 2    31680546435594       2023-04-01        MARIA ALYCE SILVA MOREIRA
# 3    31680552994265       2023-04-02             DYLAN PEREIRA VIEIRA
# 4    31680410614381       2023-04-02      HELENA VICTORIA FELIX SOUSA
# ..              ...              ...                              ...
# 296  31686605179575       2023-06-12         AURORA OLIVEIRA DE SOUSA
# 297  31686753171124       2023-06-13  MARCOS ANTONIO DOS SANTOS ALVES
# 298  31686704429298       2023-06-13       RONALD EMANUEL ALVES COSTA
# 299  31686702251809       2023-06-13        MIQUEIAS DEOLINO DE SOUSA
# 300  31686724769849       2023-06-14    LUCAS MIGUEL DA SILVA  ARAGAO
#
#     DATA_NASCIMENTO SEXO                                      NOME_MAE  \
# 0        2023-02-23    M                           NAYADY ARANDA ROCHA
# 1        2015-05-24    M                    MARIA JOSE SOUSA DE FARIAS
# 2        2020-08-28    F  FRANCISCA DAS CHAGAS MEIRELANE SILVA MOREIRA
# 3        2021-01-27    M                          ALINE REGINA PEREIRA
# 4        2020-03-01    F                        CAROLINA BARROSO FELIX
# ..              ...  ...                                           ...
# 296      2019-01-10    F                   JANIELE OLIVEIRA DE HOLANDA
# 297      1967-10-28    M                 MARIA EUNICE DOS SANTOS ALVES
# 298      2016-12-16    M                     NATALIA ALVES DE OLIVEIRA
# 299      2021-06-16    M              PRISCILA DEOLINO DAMASCENO RAMOS
# 300      2018-05-18    M                        WANDERSIN SILVA ARAGAO
#
#     MUNICIPIO_RESIDENCIA   BAIRRO_RESIDENCIA  \
# 0                 230440             GENIBAU
# 1                 230440        PARQUE ARAXA
# 2                 230440  PARQUE DOIS IRMAOS
# 3                 230765       LUZARDO VIANA
# 4                 230440      JARDIM AMERICA
# ..                   ...                 ...
# 296               230440             ITAPERI
# 297               230440     RODOLFO TEOFILO
# 298               230440      HENRIQUE JORGE
# 299               230440      NOVA METROPOLE
# 300               230440                COCO
#
#                            LOGRADOURO LOGRADOURO_NUMERO       CEP  \
# 0                   RUA DAS PEDRINHAS               633      None
# 1                   RUA CARVALHO MOTA               467      None
# 2                      DAS OLIMPIADAS               505  60761135
# 3                 ALMIR FREITAS DUTRA                78  61910065
# 4              RUA COMENDADOR MACHADO               538      None
# ..                                ...               ...       ...
# 296  VEREADORA ZELIA CORREIA DE SOUSA               678  60000000
# 297         RUA CORONEL NUNES DE MELO              1342  60000000
# 298                     RUA TEREZINHA               406      None
# 299                         AVENIDA C                35      None
# 300               RUA ANDRADE FURTADO              None      None
#
#                  CNS          CPF                  CRIADO_EM  \
# 0               None  12727638388 2023-07-31 16:47:55.255447
# 1               None  11281335398 2023-07-31 16:47:55.287414
# 2               None  11455973351 2023-07-31 16:47:55.407413
# 3               None  11680150308 2023-07-31 16:47:55.275412
# 4    898006194502845         None 2023-07-31 16:47:55.318412
# ..               ...          ...                        ...
# 296  600000000000000         None 2023-07-31 16:47:55.352423
# 297             None  32059086353 2023-07-31 16:47:55.287414
# 298             None  63091774350 2023-07-31 16:47:55.330441
# 299             None  11870689348 2023-07-31 16:47:55.362439
# 300  000000000000000         None 2023-07-31 16:47:55.329411
#
#                  ATUALIZADO_EM
# 0   2023-07-31 16:47:55.255447
# 1   2023-07-31 16:47:55.287414
# 2   2023-07-31 16:47:55.407413
# 3   2023-07-31 16:47:55.275412
# 4   2023-07-31 16:47:55.318412
# ..                         ...
# 296 2023-07-31 16:47:55.352423
# 297 2023-07-31 16:47:55.287414
# 298 2023-07-31 16:47:55.330441
# 299 2023-07-31 16:47:55.362439
# 300 2023-07-31 16:47:55.329411
#
# [301 rows x 15 columns]

# %%
obj = ProcessSivep(qdata, field_id="ID_SIVEP")

# %%
obj.basic_standardize()

# %%
obj.specific_standardize()

# %%
ex = obj.data.copy()

# %%
record = {
    "data": [
    {"NOME_PACIENTE": "HIGOR DA SILVA MONTEIRO", "DATA DE NASCIMENTO": "26/07/1996",
    "NOME_MAE": "DANIELA DA SILVA CAXILE"}
    ]          
}

s = requests.post(url, data=record)

# %%
# Create class to perform comparison between records in the same database
class Compare:
    def __init__(self):
        pass

    def test(self):
        pass

# %%
r
