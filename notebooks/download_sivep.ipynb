# %% [markdown]
# ## **Script:**
# **Download SIVEP-GRIPE data**

# %%
import os
import sys
sys.path.append( os.path.dirname(os.path.abspath('')) )
sys.path.append( os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('')), '..', 'linkage-saude')) )

import glob
import shutil
import zipfile
import numpy as np
import pandas as pd
import datetime as dt
from simpledbf import Dbf5

from epimonitor import WarehouseSUS

# %%
# -- connect with the database
datapath = os.path.join(os.environ["HOMEPATH"], "Documents", "data")
suspath = os.path.join(datapath, "DATASUS_WAREHOUSE", "datasus_pessoas.db")
engine_url = f"sqlite:///{suspath}"

warehouse = WarehouseSUS(engine_url)
engine = warehouse.db_init()

# %%
# -- folder where downloaded data is stored
basefolder = os.path.join(os.environ["HOMEPATH"], 'Documents', 'data', 'SIVEP-Gripe', 'DOWNLOAD_AUTO')

# -- collection folders are named with dates
date_folders = [ dt.date(int(n.split("-")[2]), int(n.split("-")[1]), int(n.split("-")[0]) ) for n in os.listdir(basefolder)  ]

# -- select the most recent data
nargmax = date_folders.index(max(date_folders))
selected_folder = os.listdir(basefolder)[nargmax]

# -- create separated folder for uncompressed files
extracted_path = os.path.join(basefolder, selected_folder, "EXTRACTED")
if not os.path.isdir(extracted_path):
    os.mkdir(extracted_path)

list_of_zipfiles = [ os.path.basename(x) for x in glob.glob(os.path.join(basefolder, selected_folder, "*.zip")) ]

for current_file in list_of_zipfiles:
    # -- extract file
    print(f'extracting {current_file} ... ', end='')
    with zipfile.ZipFile( os.path.join(basefolder, selected_folder, current_file), 'r') as fzip:
        fzip.extractall(extracted_path)

    # -- load and preprocess DBF file
    dbf_file = glob.glob(os.path.join(extracted_path, "*.dbf"))[0] # it should be just one
    
    print(f'loading and preprocessing of {os.path.basename(dbf_file)} ... ', end='')
    cur_sivep = Dbf5(dbf_file, codec='latin').to_dataframe()
    cur_sivep["DT_NASC"] = pd.to_datetime(cur_sivep["DT_NASC"], format="%d/%m/%Y", errors="coerce")
    cur_sivep["DT_NOTIFIC"] = pd.to_datetime(cur_sivep["DT_NOTIFIC"], format="%d/%m/%Y", errors="coerce")

    min_year, max_year = cur_sivep["DT_NOTIFIC"].min().year, cur_sivep["DT_NOTIFIC"].max().year
    list_of_ids = []
    for current_year in np.arange(min_year, max_year+1, 1):
        list_of_ids += [ pd.DataFrame(warehouse.query_id('sivep_gripe', current_year)) ]
    list_of_ids = pd.concat(list_of_ids)
    if list_of_ids.shape[0]>0:
        list_of_ids = list_of_ids["ID_SIVEP"]

    # -- remove from the dbf the records already present in the database
    cur_sivep_new = cur_sivep[~cur_sivep["NU_NOTIFIC"].isin(list_of_ids)].copy()
    print(f"{cur_sivep_new.shape[0]} new records to be added to the database ... ", end='')

    # -- insert records
    warehouse.insert('sivep_gripe', cur_sivep_new, batchsize=200, verbose=True)
    
    # -- delete extracted file
    print("done.")
    os.remove(dbf_file)
    
os.remove(extracted_path)

#for cur_zipfile in list_of_zipfiles:
#    with zipfile.ZipFile( os.path.join(basefolder, selected_folder, cur_zipfile), 'r') as fzip:
#        fzip.extractall(extracted_path)

# -- now, process each extracted file and insert in the database
#dbf_files = glob.glob(os.path.join(extracted_path, "*.dbf"))



#for cur_fullpath in dbf_files:
#    cur_sivep = Dbf5(cur_fullpath, codec='latin').to_dataframe()
#
#    cur_sivep["DT_NASC"] = pd.to_datetime(cur_sivep["DT_NASC"], format="%d/%m/%Y", errors="coerce")
#    cur_sivep["DT_NOTIFIC"] = pd.to_datetime(cur_sivep["DT_NOTIFIC"], format="%d/%m/%Y", errors="coerce")
#
#    warehouse.insert('sivep_gripe', cur_sivep, batchsize=100, verbose=True)
#
#
## -- delete extracted files
#shutil.rmtree(extracted_path)




# Uncomment if you want to reset table
#warehouse.delete_table('sivep_gripe', is_sure=True, authkey="###!Y!.")
#warehouse.db_init()

#warehouse.insert('sivep_gripe', sample_df1, batchsize=50, verbose=True)
# Out:
# extracting 1971704DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971704_00.dbf ... 2 new records to be added to the database ... Insertion of batch 1 of 1 ... done.
# done.
# extracting 1971705DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971705_00.dbf ... 3 new records to be added to the database ... Insertion of batch 1 of 1 ... done.
# done.
# extracting 1971706DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971706_00.dbf ... 563 new records to be added to the database ... Insertion of batch 1 of 3 ... done.
# Insertion of batch 2 of 3 ... done.
# Insertion of batch 3 of 3 ... done.
# done.
# extracting 1971707DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971707_00.dbf ... 310 new records to be added to the database ... Insertion of batch 1 of 2 ... done.
# Insertion of batch 2 of 2 ... done.
# done.
# extracting 1971708DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971708_00.dbf ... 18143 new records to be added to the database ... Insertion of batch 1 of 91 ... done.
# Insertion of batch 2 of 91 ... done.
# Insertion of batch 3 of 91 ... done.
# Insertion of batch 4 of 91 ... done.
# Insertion of batch 5 of 91 ... done.
# Insertion of batch 6 of 91 ... done.
# Insertion of batch 7 of 91 ... done.
# Insertion of batch 8 of 91 ... done.
# Insertion of batch 9 of 91 ... done.
# Insertion of batch 10 of 91 ... done.
# Insertion of batch 11 of 91 ... done.
# Insertion of batch 12 of 91 ... done.
# Insertion of batch 13 of 91 ... done.
# Insertion of batch 14 of 91 ... done.
# Insertion of batch 15 of 91 ... done.
# Insertion of batch 16 of 91 ... done.
# Insertion of batch 17 of 91 ... done.
# Insertion of batch 18 of 91 ... done.
# Insertion of batch 19 of 91 ... done.
# Insertion of batch 20 of 91 ... done.
# Insertion of batch 21 of 91 ... done.
# Insertion of batch 22 of 91 ... done.
# Insertion of batch 23 of 91 ... done.
# Insertion of batch 24 of 91 ... done.
# Insertion of batch 25 of 91 ... done.
# Insertion of batch 26 of 91 ... done.
# Insertion of batch 27 of 91 ... done.
# Insertion of batch 28 of 91 ... done.
# Insertion of batch 29 of 91 ... done.
# Insertion of batch 30 of 91 ... done.
# Insertion of batch 31 of 91 ... done.
# Insertion of batch 32 of 91 ... done.
# Insertion of batch 33 of 91 ... done.
# Insertion of batch 34 of 91 ... done.
# Insertion of batch 35 of 91 ... done.
# Insertion of batch 36 of 91 ... done.
# Insertion of batch 37 of 91 ... done.
# Insertion of batch 38 of 91 ... done.
# Insertion of batch 39 of 91 ... done.
# Insertion of batch 40 of 91 ... done.
# Insertion of batch 41 of 91 ... done.
# Insertion of batch 42 of 91 ... done.
# Insertion of batch 43 of 91 ... done.
# Insertion of batch 44 of 91 ... done.
# Insertion of batch 45 of 91 ... done.
# Insertion of batch 46 of 91 ... done.
# Insertion of batch 47 of 91 ... done.
# Insertion of batch 48 of 91 ... done.
# Insertion of batch 49 of 91 ... done.
# Insertion of batch 50 of 91 ... done.
# Insertion of batch 51 of 91 ... done.
# Insertion of batch 52 of 91 ... done.
# Insertion of batch 53 of 91 ... done.
# Insertion of batch 54 of 91 ... done.
# Insertion of batch 55 of 91 ... done.
# Insertion of batch 56 of 91 ... done.
# Insertion of batch 57 of 91 ... done.
# Insertion of batch 58 of 91 ... done.
# Insertion of batch 59 of 91 ... done.
# Insertion of batch 60 of 91 ... done.
# Insertion of batch 61 of 91 ... done.
# Insertion of batch 62 of 91 ... done.
# Insertion of batch 63 of 91 ... done.
# Insertion of batch 64 of 91 ... done.
# Insertion of batch 65 of 91 ... done.
# Insertion of batch 66 of 91 ... done.
# Insertion of batch 67 of 91 ... done.
# Insertion of batch 68 of 91 ... done.
# Insertion of batch 69 of 91 ... done.
# Insertion of batch 70 of 91 ... done.
# Insertion of batch 71 of 91 ... done.
# Insertion of batch 72 of 91 ... done.
# Insertion of batch 73 of 91 ... done.
# Insertion of batch 74 of 91 ... done.
# Insertion of batch 75 of 91 ... done.
# Insertion of batch 76 of 91 ... done.
# Insertion of batch 77 of 91 ... done.
# Insertion of batch 78 of 91 ... done.
# Insertion of batch 79 of 91 ... done.
# Insertion of batch 80 of 91 ... done.
# Insertion of batch 81 of 91 ... done.
# Insertion of batch 82 of 91 ... done.
# Insertion of batch 83 of 91 ... done.
# Insertion of batch 84 of 91 ... done.
# Insertion of batch 85 of 91 ... done.
# Insertion of batch 86 of 91 ... done.
# Insertion of batch 87 of 91 ... done.
# Insertion of batch 88 of 91 ... done.
# Insertion of batch 89 of 91 ... done.
# Insertion of batch 90 of 91 ... done.
# Insertion of batch 91 of 91 ... done.
# done.
# extracting 1971711DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971711_00.dbf ... 11100 new records to be added to the database ... Insertion of batch 1 of 56 ... done.
# Insertion of batch 2 of 56 ... done.
# Insertion of batch 3 of 56 ... done.
# Insertion of batch 4 of 56 ... done.
# Insertion of batch 5 of 56 ... done.
# Insertion of batch 6 of 56 ... done.
# Insertion of batch 7 of 56 ... done.
# Insertion of batch 8 of 56 ... done.
# Insertion of batch 9 of 56 ... done.
# Insertion of batch 10 of 56 ... done.
# Insertion of batch 11 of 56 ... done.
# Insertion of batch 12 of 56 ... done.
# Insertion of batch 13 of 56 ... done.
# Insertion of batch 14 of 56 ... done.
# Insertion of batch 15 of 56 ... done.
# Insertion of batch 16 of 56 ... done.
# Insertion of batch 17 of 56 ... done.
# Insertion of batch 18 of 56 ... done.
# Insertion of batch 19 of 56 ... done.
# Insertion of batch 20 of 56 ... done.
# Insertion of batch 21 of 56 ... done.
# Insertion of batch 22 of 56 ... done.
# Insertion of batch 23 of 56 ... done.
# Insertion of batch 24 of 56 ... done.
# Insertion of batch 25 of 56 ... done.
# Insertion of batch 26 of 56 ... done.
# Insertion of batch 27 of 56 ... done.
# Insertion of batch 28 of 56 ... done.
# Insertion of batch 29 of 56 ... done.
# Insertion of batch 30 of 56 ... done.
# Insertion of batch 31 of 56 ... done.
# Insertion of batch 32 of 56 ... done.
# Insertion of batch 33 of 56 ... done.
# Insertion of batch 34 of 56 ... done.
# Insertion of batch 35 of 56 ... done.
# Insertion of batch 36 of 56 ... done.
# Insertion of batch 37 of 56 ... done.
# Insertion of batch 38 of 56 ... done.
# Insertion of batch 39 of 56 ... done.
# Insertion of batch 40 of 56 ... done.
# Insertion of batch 41 of 56 ... done.
# Insertion of batch 42 of 56 ... done.
# Insertion of batch 43 of 56 ... done.
# Insertion of batch 44 of 56 ... done.
# Insertion of batch 45 of 56 ... done.
# Insertion of batch 46 of 56 ... done.
# Insertion of batch 47 of 56 ... done.
# Insertion of batch 48 of 56 ... done.
# Insertion of batch 49 of 56 ... done.
# Insertion of batch 50 of 56 ... done.
# Insertion of batch 51 of 56 ... done.
# Insertion of batch 52 of 56 ... done.
# Insertion of batch 53 of 56 ... done.
# Insertion of batch 54 of 56 ... done.
# Insertion of batch 55 of 56 ... done.
# Insertion of batch 56 of 56 ... done.
# done.
# extracting 1971713DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971713_00.dbf ... 34039 new records to be added to the database ... Insertion of batch 1 of 171 ... done.
# Insertion of batch 2 of 171 ... done.
# Insertion of batch 3 of 171 ... done.
# Insertion of batch 4 of 171 ... done.
# Insertion of batch 5 of 171 ... done.
# Insertion of batch 6 of 171 ... done.
# Insertion of batch 7 of 171 ... done.
# Insertion of batch 8 of 171 ... done.
# Insertion of batch 9 of 171 ... done.
# Insertion of batch 10 of 171 ... done.
# Insertion of batch 11 of 171 ... done.
# Insertion of batch 12 of 171 ... done.
# Insertion of batch 13 of 171 ... done.
# Insertion of batch 14 of 171 ... done.
# Insertion of batch 15 of 171 ... done.
# Insertion of batch 16 of 171 ... done.
# Insertion of batch 17 of 171 ... done.
# Insertion of batch 18 of 171 ... done.
# Insertion of batch 19 of 171 ... done.
# Insertion of batch 20 of 171 ... done.
# Insertion of batch 21 of 171 ... done.
# Insertion of batch 22 of 171 ... done.
# Insertion of batch 23 of 171 ... done.
# Insertion of batch 24 of 171 ... done.
# Insertion of batch 25 of 171 ... done.
# Insertion of batch 26 of 171 ... done.
# Insertion of batch 27 of 171 ... done.
# Insertion of batch 28 of 171 ... done.
# Insertion of batch 29 of 171 ... done.
# Insertion of batch 30 of 171 ... done.
# Insertion of batch 31 of 171 ... done.
# Insertion of batch 32 of 171 ... done.
# Insertion of batch 33 of 171 ... done.
# Insertion of batch 34 of 171 ... done.
# Insertion of batch 35 of 171 ... done.
# Insertion of batch 36 of 171 ... done.
# Insertion of batch 37 of 171 ... done.
# Insertion of batch 38 of 171 ... done.
# Insertion of batch 39 of 171 ... done.
# Insertion of batch 40 of 171 ... done.
# Insertion of batch 41 of 171 ... done.
# Insertion of batch 42 of 171 ... done.
# Insertion of batch 43 of 171 ... done.
# Insertion of batch 44 of 171 ... done.
# Insertion of batch 45 of 171 ... done.
# Insertion of batch 46 of 171 ... done.
# Insertion of batch 47 of 171 ... done.
# Insertion of batch 48 of 171 ... done.
# Insertion of batch 49 of 171 ... done.
# Insertion of batch 50 of 171 ... done.
# Insertion of batch 51 of 171 ... done.
# Insertion of batch 52 of 171 ... done.
# Insertion of batch 53 of 171 ... done.
# Insertion of batch 54 of 171 ... done.
# Insertion of batch 55 of 171 ... done.
# Insertion of batch 56 of 171 ... done.
# Insertion of batch 57 of 171 ... done.
# Insertion of batch 58 of 171 ... done.
# Insertion of batch 59 of 171 ... done.
# Insertion of batch 60 of 171 ... done.
# Insertion of batch 61 of 171 ... done.
# Insertion of batch 62 of 171 ... done.
# Insertion of batch 63 of 171 ... done.
# Insertion of batch 64 of 171 ... done.
# Insertion of batch 65 of 171 ... done.
# Insertion of batch 66 of 171 ... done.
# Insertion of batch 67 of 171 ... done.
# Insertion of batch 68 of 171 ... done.
# Insertion of batch 69 of 171 ... done.
# Insertion of batch 70 of 171 ... done.
# Insertion of batch 71 of 171 ... done.
# Insertion of batch 72 of 171 ... done.
# Insertion of batch 73 of 171 ... done.
# Insertion of batch 74 of 171 ... done.
# Insertion of batch 75 of 171 ... done.
# Insertion of batch 76 of 171 ... done.
# Insertion of batch 77 of 171 ... done.
# Insertion of batch 78 of 171 ... done.
# Insertion of batch 79 of 171 ... done.
# Insertion of batch 80 of 171 ... done.
# Insertion of batch 81 of 171 ... done.
# Insertion of batch 82 of 171 ... done.
# Insertion of batch 83 of 171 ... done.
# Insertion of batch 84 of 171 ... done.
# Insertion of batch 85 of 171 ... done.
# Insertion of batch 86 of 171 ... done.
# Insertion of batch 87 of 171 ... done.
# Insertion of batch 88 of 171 ... done.
# Insertion of batch 89 of 171 ... done.
# Insertion of batch 90 of 171 ... done.
# Insertion of batch 91 of 171 ... done.
# Insertion of batch 92 of 171 ... done.
# Insertion of batch 93 of 171 ... done.
# Insertion of batch 94 of 171 ... done.
# Insertion of batch 95 of 171 ... done.
# Insertion of batch 96 of 171 ... done.
# Insertion of batch 97 of 171 ... done.
# Insertion of batch 98 of 171 ... done.
# Insertion of batch 99 of 171 ... done.
# Insertion of batch 100 of 171 ... done.
# Insertion of batch 101 of 171 ... done.
# Insertion of batch 102 of 171 ... done.
# Insertion of batch 103 of 171 ... done.
# Insertion of batch 104 of 171 ... done.
# Insertion of batch 105 of 171 ... done.
# Insertion of batch 106 of 171 ... done.
# Insertion of batch 107 of 171 ... done.
# Insertion of batch 108 of 171 ... done.
# Insertion of batch 109 of 171 ... done.
# Insertion of batch 110 of 171 ... done.
# Insertion of batch 111 of 171 ... done.
# Insertion of batch 112 of 171 ... done.
# Insertion of batch 113 of 171 ... done.
# Insertion of batch 114 of 171 ... done.
# Insertion of batch 115 of 171 ... done.
# Insertion of batch 116 of 171 ... done.
# Insertion of batch 117 of 171 ... done.
# Insertion of batch 118 of 171 ... done.
# Insertion of batch 119 of 171 ... done.
# Insertion of batch 120 of 171 ... done.
# Insertion of batch 121 of 171 ... done.
# Insertion of batch 122 of 171 ... done.
# Insertion of batch 123 of 171 ... done.
# Insertion of batch 124 of 171 ... done.
# Insertion of batch 125 of 171 ... done.
# Insertion of batch 126 of 171 ... done.
# Insertion of batch 127 of 171 ... done.
# Insertion of batch 128 of 171 ... done.
# Insertion of batch 129 of 171 ... done.
# Insertion of batch 130 of 171 ... done.
# Insertion of batch 131 of 171 ... done.
# Insertion of batch 132 of 171 ... done.
# Insertion of batch 133 of 171 ... done.
# Insertion of batch 134 of 171 ... done.
# Insertion of batch 135 of 171 ... done.
# Insertion of batch 136 of 171 ... done.
# Insertion of batch 137 of 171 ... done.
# Insertion of batch 138 of 171 ... done.
# Insertion of batch 139 of 171 ... done.
# Insertion of batch 140 of 171 ... done.
# Insertion of batch 141 of 171 ... done.
# Insertion of batch 142 of 171 ... done.
# Insertion of batch 143 of 171 ... done.
# Insertion of batch 144 of 171 ... done.
# Insertion of batch 145 of 171 ... done.
# Insertion of batch 146 of 171 ... done.
# Insertion of batch 147 of 171 ... done.
# Insertion of batch 148 of 171 ... done.
# Insertion of batch 149 of 171 ... done.
# Insertion of batch 150 of 171 ... done.
# Insertion of batch 151 of 171 ... done.
# Insertion of batch 152 of 171 ... done.
# Insertion of batch 153 of 171 ... done.
# Insertion of batch 154 of 171 ... done.
# Insertion of batch 155 of 171 ... done.
# Insertion of batch 156 of 171 ... done.
# Insertion of batch 157 of 171 ... done.
# Insertion of batch 158 of 171 ... done.
# Insertion of batch 159 of 171 ... done.
# Insertion of batch 160 of 171 ... done.
# Insertion of batch 161 of 171 ... done.
# Insertion of batch 162 of 171 ... done.
# Insertion of batch 163 of 171 ... done.
# Insertion of batch 164 of 171 ... done.
# Insertion of batch 165 of 171 ... done.
# Insertion of batch 166 of 171 ... done.
# Insertion of batch 167 of 171 ... done.
# Insertion of batch 168 of 171 ... done.
# Insertion of batch 169 of 171 ... done.
# Insertion of batch 170 of 171 ... done.
# Insertion of batch 171 of 171 ... done.
# done.
# extracting 1971716DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971716_00.dbf ... 7842 new records to be added to the database ... Insertion of batch 1 of 40 ... done.
# Insertion of batch 2 of 40 ... done.
# Insertion of batch 3 of 40 ... done.
# Insertion of batch 4 of 40 ... done.
# Insertion of batch 5 of 40 ... done.
# Insertion of batch 6 of 40 ... done.
# Insertion of batch 7 of 40 ... done.
# Insertion of batch 8 of 40 ... done.
# Insertion of batch 9 of 40 ... done.
# Insertion of batch 10 of 40 ... done.
# Insertion of batch 11 of 40 ... done.
# Insertion of batch 12 of 40 ... done.
# Insertion of batch 13 of 40 ... done.
# Insertion of batch 14 of 40 ... done.
# Insertion of batch 15 of 40 ... done.
# Insertion of batch 16 of 40 ... done.
# Insertion of batch 17 of 40 ... done.
# Insertion of batch 18 of 40 ... done.
# Insertion of batch 19 of 40 ... done.
# Insertion of batch 20 of 40 ... done.
# Insertion of batch 21 of 40 ... done.
# Insertion of batch 22 of 40 ... done.
# Insertion of batch 23 of 40 ... done.
# Insertion of batch 24 of 40 ... done.
# Insertion of batch 25 of 40 ... done.
# Insertion of batch 26 of 40 ... done.
# Insertion of batch 27 of 40 ... done.
# Insertion of batch 28 of 40 ... done.
# Insertion of batch 29 of 40 ... done.
# Insertion of batch 30 of 40 ... done.
# Insertion of batch 31 of 40 ... done.
# Insertion of batch 32 of 40 ... done.
# Insertion of batch 33 of 40 ... done.
# Insertion of batch 34 of 40 ... done.
# Insertion of batch 35 of 40 ... done.
# Insertion of batch 36 of 40 ... done.
# Insertion of batch 37 of 40 ... done.
# Insertion of batch 38 of 40 ... done.
# Insertion of batch 39 of 40 ... done.
# Insertion of batch 40 of 40 ... done.
# done.
# extracting 1971720DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971720_00.dbf ... 15137 new records to be added to the database ... Insertion of batch 1 of 76 ... done.
# Insertion of batch 2 of 76 ... done.
# Insertion of batch 3 of 76 ... done.
# Insertion of batch 4 of 76 ... done.
# Insertion of batch 5 of 76 ... done.
# Insertion of batch 6 of 76 ... done.
# Insertion of batch 7 of 76 ... done.
# Insertion of batch 8 of 76 ... done.
# Insertion of batch 9 of 76 ... done.
# Insertion of batch 10 of 76 ... done.
# Insertion of batch 11 of 76 ... done.
# Insertion of batch 12 of 76 ... done.
# Insertion of batch 13 of 76 ... done.
# Insertion of batch 14 of 76 ... done.
# Insertion of batch 15 of 76 ... done.
# Insertion of batch 16 of 76 ... done.
# Insertion of batch 17 of 76 ... done.
# Insertion of batch 18 of 76 ... done.
# Insertion of batch 19 of 76 ... done.
# Insertion of batch 20 of 76 ... done.
# Insertion of batch 21 of 76 ... done.
# Insertion of batch 22 of 76 ... done.
# Insertion of batch 23 of 76 ... done.
# Insertion of batch 24 of 76 ... done.
# Insertion of batch 25 of 76 ... done.
# Insertion of batch 26 of 76 ... done.
# Insertion of batch 27 of 76 ... done.
# Insertion of batch 28 of 76 ... done.
# Insertion of batch 29 of 76 ... done.
# Insertion of batch 30 of 76 ... done.
# Insertion of batch 31 of 76 ... done.
# Insertion of batch 32 of 76 ... done.
# Insertion of batch 33 of 76 ... done.
# Insertion of batch 34 of 76 ... done.
# Insertion of batch 35 of 76 ... done.
# Insertion of batch 36 of 76 ... done.
# Insertion of batch 37 of 76 ... done.
# Insertion of batch 38 of 76 ... done.
# Insertion of batch 39 of 76 ... done.
# Insertion of batch 40 of 76 ... done.
# Insertion of batch 41 of 76 ... done.
# Insertion of batch 42 of 76 ... done.
# Insertion of batch 43 of 76 ... done.
# Insertion of batch 44 of 76 ... done.
# Insertion of batch 45 of 76 ... done.
# Insertion of batch 46 of 76 ... done.
# Insertion of batch 47 of 76 ... done.
# Insertion of batch 48 of 76 ... done.
# Insertion of batch 49 of 76 ... done.
# Insertion of batch 50 of 76 ... done.
# Insertion of batch 51 of 76 ... done.
# Insertion of batch 52 of 76 ... done.
# Insertion of batch 53 of 76 ... done.
# Insertion of batch 54 of 76 ... done.
# Insertion of batch 55 of 76 ... done.
# Insertion of batch 56 of 76 ... done.
# Insertion of batch 57 of 76 ... done.
# Insertion of batch 58 of 76 ... done.
# Insertion of batch 59 of 76 ... done.
# Insertion of batch 60 of 76 ... done.
# Insertion of batch 61 of 76 ... done.
# Insertion of batch 62 of 76 ... done.
# Insertion of batch 63 of 76 ... done.
# Insertion of batch 64 of 76 ... done.
# Insertion of batch 65 of 76 ... done.
# Insertion of batch 66 of 76 ... done.
# Insertion of batch 67 of 76 ... done.
# Insertion of batch 68 of 76 ... done.
# Insertion of batch 69 of 76 ... done.
# Insertion of batch 70 of 76 ... done.
# Insertion of batch 71 of 76 ... done.
# Insertion of batch 72 of 76 ... done.
# Insertion of batch 73 of 76 ... done.
# Insertion of batch 74 of 76 ... done.
# Insertion of batch 75 of 76 ... done.
# Insertion of batch 76 of 76 ... done.
# done.
# extracting 1971721DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971721_00.dbf ... 6051 new records to be added to the database ... Insertion of batch 1 of 31 ... done.
# Insertion of batch 2 of 31 ... done.
# Insertion of batch 3 of 31 ... done.
# Insertion of batch 4 of 31 ... done.
# Insertion of batch 5 of 31 ... done.
# Insertion of batch 6 of 31 ... done.
# Insertion of batch 7 of 31 ... done.
# Insertion of batch 8 of 31 ... done.
# Insertion of batch 9 of 31 ... done.
# Insertion of batch 10 of 31 ... done.
# Insertion of batch 11 of 31 ... done.
# Insertion of batch 12 of 31 ... done.
# Insertion of batch 13 of 31 ... done.
# Insertion of batch 14 of 31 ... done.
# Insertion of batch 15 of 31 ... done.
# Insertion of batch 16 of 31 ... done.
# Insertion of batch 17 of 31 ... done.
# Insertion of batch 18 of 31 ... done.
# Insertion of batch 19 of 31 ... done.
# Insertion of batch 20 of 31 ... done.
# Insertion of batch 21 of 31 ... done.
# Insertion of batch 22 of 31 ... done.
# Insertion of batch 23 of 31 ... done.
# Insertion of batch 24 of 31 ... done.
# Insertion of batch 25 of 31 ... done.
# Insertion of batch 26 of 31 ... done.
# Insertion of batch 27 of 31 ... done.
# Insertion of batch 28 of 31 ... done.
# Insertion of batch 29 of 31 ... done.
# Insertion of batch 30 of 31 ... done.
# Insertion of batch 31 of 31 ... done.
# done.
# extracting 1971722DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971722_00.dbf ... 6035 new records to be added to the database ... Insertion of batch 1 of 31 ... done.
# Insertion of batch 2 of 31 ... done.
# Insertion of batch 3 of 31 ... done.
# Insertion of batch 4 of 31 ... done.
# Insertion of batch 5 of 31 ... error: (sqlite3.IntegrityError) UNIQUE constraint failed: sivep_gripe.ID_SIVEP ... adding one by one ... done.
# Insertion of batch 6 of 31 ... done.
# Insertion of batch 7 of 31 ... done.
# Insertion of batch 8 of 31 ... done.
# Insertion of batch 9 of 31 ... done.
# Insertion of batch 10 of 31 ... done.
# Insertion of batch 11 of 31 ... error: (sqlite3.IntegrityError) UNIQUE constraint failed: sivep_gripe.ID_SIVEP ... adding one by one ... done.
# Insertion of batch 12 of 31 ... done.
# Insertion of batch 13 of 31 ... done.
# Insertion of batch 14 of 31 ... done.
# Insertion of batch 15 of 31 ... done.
# Insertion of batch 16 of 31 ... error: (sqlite3.IntegrityError) UNIQUE constraint failed: sivep_gripe.ID_SIVEP ... adding one by one ... done.
# Insertion of batch 17 of 31 ... done.
# Insertion of batch 18 of 31 ... done.
# Insertion of batch 19 of 31 ... done.
# Insertion of batch 20 of 31 ... done.
# Insertion of batch 21 of 31 ... done.
# Insertion of batch 22 of 31 ... done.
# Insertion of batch 23 of 31 ... done.
# Insertion of batch 24 of 31 ... done.
# Insertion of batch 25 of 31 ... done.
# Insertion of batch 26 of 31 ... done.
# Insertion of batch 27 of 31 ... done.
# Insertion of batch 28 of 31 ... done.
# Insertion of batch 29 of 31 ... done.
# Insertion of batch 30 of 31 ... done.
# Insertion of batch 31 of 31 ... done.
# done.
# extracting 1971724DBF.zip ... loading and preprocessing of SRAGHOSPITALIZADO1971724_00.dbf ... 657 new records to be added to the database ... Insertion of batch 1 of 4 ... done.
# Insertion of batch 2 of 4 ... done.
# Insertion of batch 3 of 4 ... done.
# Insertion of batch 4 of 4 ... done.
# done.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\higor.monteiro\Documents\projects\epimonitor-sari\scripts\download_sivep.ipynb Cell 4 in <cell line: 51>()
#      <a href='vscode-notebook-cell:/c%3A/Users/higor.monteiro/Documents/projects/epimonitor-sari/scripts/download_sivep.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a>     print("done.")
#      <a href='vscode-notebook-cell:/c%3A/Users/higor.monteiro/Documents/projects/epimonitor-sari/scripts/download_sivep.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a>     os.remove(dbf_file)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/higor.monteiro/Documents/projects/epimonitor-sari/scripts/download_sivep.ipynb#W2sZmlsZQ%3D%3D?line=50'>51</a> os.remove(extracted_path)
#
# PermissionError: [WinError 5] Acesso negado: '\\Users\\higor.monteiro\\Documents\\data\\SIVEP-Gripe\\DOWNLOAD_AUTO\\08-08-2023\\EXTRACTED'

# %%
warehouse.number_of_records('sivep_gripe')
# Out:
# 99878

# %%
id2023 = pd.DataFrame(warehouse.query_id('sivep_gripe', 2020))

id2023
# Out:
#              ID_SIVEP DATA_NOTIFICACAO
# 0        315801380374       2020-01-23
# 1        315780509443       2020-01-03
# 2        315783131308       2020-01-03
# 3        315783158990       2020-01-02
# 4        315786647665       2020-01-09
# ...               ...              ...
# 28098  31656335174806       2020-12-16
# 28099  31656416269016       2020-12-29
# 28100  31656417755292       2020-07-23
# 28101  31676552978279       2020-12-09
# 28102  31676652464746       2020-12-01
#
# [28103 rows x 2 columns]

# %%
warehouse.delete_table('sivep_gripe', is_sure=True, authkey="###!Y!.")

# %%
list_of_ids
# Out:
# 0       31677085952682
# 1       31677175381109
# 2       31677256163177
# 3       31677256575574
# 4       31677260374996
#              ...
# 6815    31691444376100
# 6816    31691459456365
# 6817    31691461095478
# 6818    31691470614946
# 6819    31691483482691
# Name: ID_SIVEP, Length: 6820, dtype: object

# %%
collector.close_browser()

# %%
shutil.rmtree(extracted_path)

# %%
cur_sivep[cur_sivep["NU_NOTIFIC"]=="316196231305"][["NM_PACIENT", "DT_NOTIFIC", "SEM_NOT"]]
# Out:
#                           NM_PACIENT DT_NOTIFIC SEM_NOT
# 17903  MARINETE DO NASCIMENTO VIEIRA 2021-03-01      09

# %%
warehouse.query_all()
# Out:
# [('316129905398', datetime.datetime(2021, 2, 10, 0, 0), 'MARINETE DO NASCIMENTO VIEIRA', datetime.datetime(1970, 4, 15, 0, 0), 'F', 'MARIA BORGES DO NASCIMENTO FRANCA', 'DAS FLORES', '84', 'VILA VELHA', '230440', '60349295', None, '74788744368', '7980310', datetime.datetime(2023, 8, 8, 15, 25, 35, 612321), datetime.datetime(2023, 8, 8, 15, 25, 35, 612321)),
#  ('316196231305', datetime.datetime(2021, 3, 1, 0, 0), 'MARINETE DO NASCIMENTO VIEIRA', datetime.datetime(1979, 4, 15, 0, 0), 'F', 'MARIA BORGES DO NASCIMENTO', 'RUA DAS FLORES', '84', 'BARRO DO CEARA', '230440', None, None, None, '2561492', datetime.datetime(2023, 8, 8, 15, 28, 3, 566361), datetime.datetime(2023, 8, 8, 15, 28, 3, 566361))]

# %%
from sqlalchemy import select

# %%
table_model = warehouse.tables['sivep_gripe']
sel = select(table_model.c['ID_SIVEP'], table_model.c['DATA_NOTIFICACAO'])

# %%
engine = warehouse._engine

with engine.connect() as conn:
    rp = conn.execute(sel)
    for cur_record in rp:
        pass
    results = [ record for record in rp ]

# %%
results[:5]
# Out:
# [('315487038336', datetime.datetime(2019, 1, 20, 0, 0)),
#  ('31646415229798', datetime.datetime(2022, 3, 4, 0, 0)),
#  ('315480952153', datetime.datetime(2019, 1, 2, 0, 0)),
#  ('315541216555', datetime.datetime(2019, 1, 2, 0, 0)),
#  ('316397719239', datetime.datetime(2021, 9, 26, 0, 0))]

# %%
cur_record
# Out:
# ('31691483482691', datetime.datetime(2023, 8, 8, 0, 0))
